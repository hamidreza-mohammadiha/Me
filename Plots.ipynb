# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function R(n)
def R(n):
    return (n * np.sin(2 * np.pi / n)) / (2 * np.pi)

def P(n):
    return (n) / ((2 * np.pi - 4) + (n))

def Q(n):
    return (n) / ((2 * np.sqrt(2)*np.pi - 8) + (n))

def P(n, k=0.42, n0=2):
    return 1 - np.exp(-k * (n - n0))

# Generate values for n
n_values = np.arange(0, 21)  # start from 3 for the polygon (triangle)
R_values = R(n_values)
P_values = P(n_values)
Q_values = Q(n_values)
P_values = P(n_values)  # Exponential approximation

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(n_values, R_values, label='R(n) = n * sin(2π/n) / (2π)', color='blue')
# plt.plot(n_values, P_values, label='P(n) = n / ((2π-4)+n)', color='red')
# plt.plot(n_values, Q_values, label='P(n) = n / ((2*2^-1*π-8)+n))', color='green')
# plt.axhline(y=2/np.pi, color='orange', linestyle='--', label='R(4) = 2/π', linewidth=1.5)
# plt.axhline(y=(2 * np.sqrt(2)/np.pi), color='orange', linestyle='--', label='R(4) = 2.2^(0.5))/π', linewidth=1.5)
plt.plot(n_values, P_values, label='P(n) = 1 - e^(-0.42(n - 2))', color='black', linestyle='--')
plt.title('Ratio of the Area of Polygon to Area of Circle')
plt.xlabel('Number of Sides (n)')
plt.ylabel('R(n)')
plt.grid()
plt.gcf().set_facecolor('#343434')
plt.legend()
plt.xlim(0, 21)
plt.ylim(0, 1)
plt.xticks(np.arange(0, 21, 1))
plt.yticks(np.linspace(0, 1, 22))
plt.show()
plt.saveplot('playgun.png')
# Out:
# /tmp/ipykernel_2935/1459652564.py:6: RuntimeWarning: divide by zero encountered in divide
#   return (n * np.sin(2 * np.pi / n)) / (2 * np.pi)
# /tmp/ipykernel_2935/1459652564.py:6: RuntimeWarning: invalid value encountered in sin
#   return (n * np.sin(2 * np.pi / n)) / (2 * np.pi)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 43
#      41 plt.yticks(np.linspace(0, 1, 22))
#      42 plt.show()
# ---> 43 plt.saveplot('playgun.png')
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'saveplot'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function R(n) - Ratio of polygon area to circle area
def R(n):
    return (n * np.sin(2 * np.pi / n)) / (2 * np.pi)

# Define function Q(n) - Approximation 1
def Q(n):
    return n / ((2 * np.sqrt(2) * np.pi - 8) + n)

# Define function P(n) - Exponential approximation
def P(n, k=0.42, n0=2):
    return 1 - np.exp(-k * (n - n0))

# Generate values for n
n_values = np.arange(0, 22)  # Start from 3 (minimum polygon sides: triangle)

# Compute values for each function
R_values = R(n_values)
P_values = P(n_values)
Q_values = Q(n_values)

# Plotting
plt.figure(figsize=(20, 33))

# ?
plt.axhline(y=0.86, color='white', linestyle='--', label=r'$?$', linewidth=6)

# Plot R(n)
plt.plot(n_values, R_values, label=r'$R(n) = \frac{n \sin(2\pi/n)}{2\pi}$', color='black', linewidth=3)

# Plot P(n) (Exponential approximation)
plt.plot(n_values, P_values, label=r'$P(n) = 1 - e^{-0.42(n-2)}$', color='blue', linestyle='--', linewidth=3)

# Plot Q(n) (Approximation 1)
# plt.plot(n_values, Q_values, label=r'$Q(n) = \frac{n}{(2\sqrt{2}\pi - 8) + n}$', color='green', linestyle='-.')

# Add reference lines

# plt.axhline(y=(2 * np.sqrt(2) / np.pi), color='red', linestyle='--', label=r'$R(4) = \frac{2\sqrt{2}}{\pi}$', linewidth=1.5)

# Chart customization
plt.title('Ratio of the Area of Polygon to Area of Circle\n\n', fontsize=52)
plt.xlabel('\nNumber of Sides (n)\n', fontsize=42)
plt.ylabel('Ratio\n', fontsize=42)
plt.grid(color='gray', linestyle='--', linewidth=1, alpha=0.3)
plt.xlim(3, 21)
plt.ylim(0, 1)
plt.xticks(np.arange(0, 22, 1), fontsize=24)
plt.yticks(np.linspace(0, 1, 21), fontsize=36)
plt.legend(fontsize=52, shadow=True)

# Set background color
plt.gcf().set_facecolor('white')
plt.gca().set_facecolor('#eeeeee')

# Save and display the plot
plt.savefig('playgon', dpi=100)
plt.show()
# Out:
# /tmp/ipykernel_34947/3978019185.py:6: RuntimeWarning: divide by zero encountered in divide
#   return (n * np.sin(2 * np.pi / n)) / (2 * np.pi)
# /tmp/ipykernel_34947/3978019185.py:6: RuntimeWarning: invalid value encountered in sin
#   return (n * np.sin(2 * np.pi / n)) / (2 * np.pi)
